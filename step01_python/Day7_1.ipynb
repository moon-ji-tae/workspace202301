# %% [markdown]
# - 설치환경
# - 주석
# - 출력문 print
# - 입력문
# - 자료형 : 수치형, 논리형, 문자열
# - 문자열 인덱싱, 슬라이싱
# - 그룹형 : 리스트, 튜플, 집합, 딕셔너리
# - 제어문 :
#     - 조건문 if~ elif ~ else
#     - 반복문 while, for , 리스트내포
# - 함수
#     - 내장함수
#     - 사용자정의함수
#     - 람다함수, filter, map
# - 모듈, 패키지
#     - import
#     - import ... as ...
#     - from ... import
# - 클래스
#     - OOP
#     - 클래스 => 객체
#     - 상속
#     - 클래스 변수
#     - 메서드 오버라이딩
# - 예외처리
#     - 오류 종류
#     - try ~ except ~ else ~ finally ~
#     - 사용자정의 오류 raise
# - 파일 IO
#     - open(), write(), read(), redl...m

# %% [markdown]
# - 마크업언어
# - <태그> : 단독태그
# - <태그> ~ </태그>
# - 주석 <!-- -->
# - 글문단 h1~h6,
#    p,
#    ul, li, ol, dl, dd, dt
# - br
# - hr
# - 하이퍼링크 a
# - 이미지 img
# - 테이블 table, tr, th, td, tbody, thead
# - 폼 form, input, textarea

# %%
import requests
print(dir(requests))
# Out:
# ['ConnectTimeout', 'ConnectionError', 'DependencyWarning', 'FileModeWarning', 'HTTPError', 'JSONDecodeError', 'NullHandler', 'PreparedRequest', 'ReadTimeout', 'Request', 'RequestException', 'RequestsDependencyWarning', 'Response', 'Session', 'Timeout', 'TooManyRedirects', 'URLRequired', '__author__', '__author_email__', '__build__', '__builtins__', '__cached__', '__cake__', '__copyright__', '__description__', '__doc__', '__file__', '__license__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__title__', '__url__', '__version__', '_check_cryptography', '_internal_utils', 'adapters', 'api', 'auth', 'certs', 'chardet_version', 'charset_normalizer_version', 'check_compatibility', 'codes', 'compat', 'cookies', 'delete', 'exceptions', 'get', 'head', 'hooks', 'logging', 'models', 'options', 'packages', 'patch', 'post', 'put', 'request', 'session', 'sessions', 'ssl', 'status_codes', 'structures', 'urllib3', 'utils', 'warnings']

# %%
url = "https://www.google.com/"
res = requests.get(url)
print(res)
print(res.encoding)
print(res.headers)
# Out:
# <Response [200]>
# ISO-8859-1
# {'Date': 'Tue, 07 Feb 2023 07:50:32 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2023-02-07-07; expires=Thu, 09-Mar-2023 07:50:32 GMT; path=/; domain=.google.com; Secure, AEC=ARSKqsJ-tuGo31SohSyGHBTWIxsdgKS8tu8OmRhk8zmqtFpyolo1BjkorA; expires=Sun, 06-Aug-2023 07:50:32 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax, NID=511=AeHiWWQy-gkJJUG0XR-1Lt8U9kAJQRt7TxKb0B0i0YInplggvQB9_0e7eLJ-cFZNwEDSMi27jBxEw7wuwTvD_al2csvABvEMZaGPuj9c1RNaGt1R1aONlbb_8iOOQXk4-QLv70XsjIO-y6-Awx601tTOU6sfeAgkw8P8FFMiiNM; expires=Wed, 09-Aug-2023 07:50:32 GMT; path=/; domain=.google.com; HttpOnly', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'Transfer-Encoding': 'chunked'}

# %%
url = "http://www.yes24.com/main/default.aspx?ysmchn=ggl&ysmcpm=google-sponsor&ysmtac=ppc&ysmtrm=yes24&pid=123487&cosemkid=go14913756274066498&gclid=Cj0KCQiA54KfBhCKARIsAJzSrdrj1QgGGoTzayJVEezqb_OI8Rr-10wZtila6L4DdKTXrr0O9eBYr9caAlf_EALw_wcB/"
res = requests.get(url)
print(res)
# Out:
# <Response [200]>

# %%
html_str = res.text
print(type(html_str))
print(html_str)
# Out:
# <class 'str'>
#
# 	<!DOCTYPE html>
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=euc-kr" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# <title>YES24</title>
#
# 	<meta name="title" content="YES24" />
# 	<meta name="description" content="책, 공연, 음악까지! 모든 문화생활을 위한 플랫폼, YES24" />
# 	<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘" />
# 	<meta property="og:image" content="https://image.yes24.com/sysimage/renew/logo_meta.png" />
#
# ...

# %%
f = open("data/yes.html" ,'w' , encoding='utf-8')
f.write(html_str)
f.close()

# %%
with open("data/yesy24.html", "w", encoding="utf-8") as f:
    f.write(html_str)

# %%
url = "https://www.google.com/"
res = requests.get(url)
print(res.encoding)
# Out:
# ISO-8859-1

# %%
url = "https://www.google.com/"
res = requests.get(url)
print(res)
html_str = res.text
with open("data/google20230207_1.html", "w", encoding=res.encoding) as f:
    f.write(html_str)
# Out:
# <Response [200]>

# %%
f = open("data/googlef.html" ,'w' , encoding='utf-8')
f.write(html_str)
f.close()

# %%
url = "https://www.useragentstring.com/"
res = requests.get(url)
print(res)
# Out:
# <Response [200]>

# %%
url = "https://www.bloter.net/"
user_agent_info = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"
headers = {'User-Agent' : user_agent_info}
res = requests.get(url, headers=headers)
print(res)
html_str = res.text
with open("data/bloterA.html", "w", encoding=res.encoding) as f:
    f.write(html_str)
# Out:
# <Response [200]>
